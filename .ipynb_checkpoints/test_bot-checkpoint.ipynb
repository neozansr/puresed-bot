# %%
import numpy as np
import pandas as pd
import datetime as dt
from dateutil import tz
import json
import ccxt

# %%
def convert_tz(utc):
    from_zone = tz.tzutc()
    to_zone = tz.tzlocal()
    utc = utc.replace(tzinfo=from_zone).astimezone(to_zone)
    
    return utc

# %% [markdown]
# ### Config

# %%
with open('_keys/binance_keys.json') as keys_file:
    keys_dict = json.load(keys_file)
exchange = ccxt.binance({'apiKey': keys_dict['apiKey'],
                         'secret': keys_dict['secret'],
                         'enableRateLimit': True,
                         'options': {'newOrderRespType': 'FULL'}})

# %%
symbol = 'LUNA/USDT'
timeframe = '15m'
since = None
limit = 100

# %% [markdown]
# ### Ticker

# %%
ticker = exchange.fetch_ticker(symbol)
latest_price = ticker['last']

# %%
latest_price
# Out:
# 17.097

# %% [markdown]
# ### OHLCV

# %%
ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit)

# %%
df = pd.DataFrame(ohlcv)
df.columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume']
df['Time'] = pd.to_datetime(df['Time'], unit = 'ms')
df['Time'] = df['Time'].apply(lambda x: convert_tz(x))

# %%
df
# Out:
#                         Time    Open    High     Low   Close      Volume
# 0  2021-04-27 11:30:00+07:00  18.931  18.932  18.800  18.848   31757.343
# 1  2021-04-27 11:45:00+07:00  18.848  18.910  18.825  18.849   28981.033
# 2  2021-04-27 12:00:00+07:00  18.845  19.221  18.838  19.201  121418.401
# 3  2021-04-27 12:15:00+07:00  19.201  19.201  19.029  19.041   59955.638
# 4  2021-04-27 12:30:00+07:00  19.045  19.078  19.000  19.058   35444.471
# ..                       ...     ...     ...     ...     ...         ...
# 95 2021-04-28 11:15:00+07:00  17.179  17.213  17.128  17.211   40179.800
# 96 2021-04-28 11:30:00+07:00  17.209  17.213  17.105  17.105   42577.291
# 97 2021-04-28 11:45:00+07:00  17.111  17.239  16.933  17.085  131965.750
# 98 2021-04-28 12:00:00+07:00  17.116  17.142  16.954  17.080   46542.373
# 99 2021-04-28 12:15:00+07:00  17.081  17.097  17.081  17.097    9808.677
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Order

# %%
open_orders = exchange.fetch_open_orders(symbol)

# %%
open_orders
# Out:
# [{'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151319979',
#    'orderListId': '-1',
#    'clientOrderId': 'web_a20c4727bf1c4d9d892fe83326533400',
#    'price': '16.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543422140',
#    'updateTime': '1619543422140',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151319979',
#   'clientOrderId': 'web_a20c4727bf1c4d9d892fe83326533400',
#   'timestamp': 1619543422140,
#   'datetime': '2021-04-27T17:10:22.140Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 16.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151322833',
#    'orderListId': '-1',
#    'clientOrderId': 'web_a9501dc4daf34a4ca2a65bc03c0fd56c',
#    'price': '15.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543480601',
#    'updateTime': '1619543480601',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151322833',
#   'clientOrderId': 'web_a9501dc4daf34a4ca2a65bc03c0fd56c',
#   'timestamp': 1619543480601,
#   'datetime': '2021-04-27T17:11:20.601Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 15.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151323692',
#    'orderListId': '-1',
#    'clientOrderId': 'web_f429c4d3a90b49ed9b3c72597629563f',
#    'price': '14.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543505039',
#    'updateTime': '1619543505039',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151323692',
#   'clientOrderId': 'web_f429c4d3a90b49ed9b3c72597629563f',
#   'timestamp': 1619543505039,
#   'datetime': '2021-04-27T17:11:45.039Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 14.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []}]

# %%
order_type = 'limit'
side = 'buy'
price = latest_price / 3
amount = 20 / price

order = exchange.create_order(symbol, order_type, side, amount, price)

# %%
order
# Out:
# {'info': {'symbol': 'LUNAUSDT',
#   'orderId': '151958026',
#   'orderListId': '-1',
#   'clientOrderId': 'x-R4BD3S82ab8f036d32537845330e23',
#   'transactTime': '1619586921158',
#   'price': '5.69900000',
#   'origQty': '3.50900000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'NEW',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'fills': []},
#  'id': '151958026',
#  'clientOrderId': 'x-R4BD3S82ab8f036d32537845330e23',
#  'timestamp': 1619586921158,
#  'datetime': '2021-04-28T05:15:21.158Z',
#  'lastTradeTimestamp': None,
#  'symbol': 'LUNA/USDT',
#  'type': 'limit',
#  'timeInForce': 'GTC',
#  'postOnly': False,
#  'side': 'buy',
#  'price': 5.699,
#  'stopPrice': None,
#  'amount': 3.509,
#  'cost': 0.0,
#  'average': None,
#  'filled': 0.0,
#  'remaining': 3.509,
#  'status': 'open',
#  'fee': None,
#  'trades': [],
#  'fees': []}

# %%
open_orders = exchange.fetch_open_orders(symbol)

# %%
open_orders
# Out:
# [{'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151319979',
#    'orderListId': '-1',
#    'clientOrderId': 'web_a20c4727bf1c4d9d892fe83326533400',
#    'price': '16.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543422140',
#    'updateTime': '1619543422140',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151319979',
#   'clientOrderId': 'web_a20c4727bf1c4d9d892fe83326533400',
#   'timestamp': 1619543422140,
#   'datetime': '2021-04-27T17:10:22.140Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 16.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151322833',
#    'orderListId': '-1',
#    'clientOrderId': 'web_a9501dc4daf34a4ca2a65bc03c0fd56c',
#    'price': '15.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543480601',
#    'updateTime': '1619543480601',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151322833',
#   'clientOrderId': 'web_a9501dc4daf34a4ca2a65bc03c0fd56c',
#   'timestamp': 1619543480601,
#   'datetime': '2021-04-27T17:11:20.601Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 15.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151323692',
#    'orderListId': '-1',
#    'clientOrderId': 'web_f429c4d3a90b49ed9b3c72597629563f',
#    'price': '14.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543505039',
#    'updateTime': '1619543505039',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151323692',
#   'clientOrderId': 'web_f429c4d3a90b49ed9b3c72597629563f',
#   'timestamp': 1619543505039,
#   'datetime': '2021-04-27T17:11:45.039Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 14.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []}]

# %%
order = exchange.cancel_order(order['id'], symbol)

# %%
order
# Out:
# {'info': {'symbol': 'LUNAUSDT',
#   'origClientOrderId': 'x-R4BD3S82ab8f036d32537845330e23',
#   'orderId': '151958026',
#   'orderListId': '-1',
#   'clientOrderId': '1CtRBXVgN7gn4Z1WqIHm7R',
#   'price': '5.69900000',
#   'origQty': '3.50900000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY'},
#  'id': '151958026',
#  'clientOrderId': '1CtRBXVgN7gn4Z1WqIHm7R',
#  'timestamp': None,
#  'datetime': None,
#  'lastTradeTimestamp': None,
#  'symbol': 'LUNA/USDT',
#  'type': 'limit',
#  'timeInForce': 'GTC',
#  'postOnly': False,
#  'side': 'buy',
#  'price': 5.699,
#  'stopPrice': None,
#  'amount': 3.509,
#  'cost': 0.0,
#  'average': None,
#  'filled': 0.0,
#  'remaining': 3.509,
#  'status': 'canceled',
#  'fee': None,
#  'trades': [],
#  'fees': []}

# %%
open_orders = exchange.fetch_open_orders(symbol)

# %%
open_orders
# Out:
# [{'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151319979',
#    'orderListId': '-1',
#    'clientOrderId': 'web_a20c4727bf1c4d9d892fe83326533400',
#    'price': '16.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543422140',
#    'updateTime': '1619543422140',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151319979',
#   'clientOrderId': 'web_a20c4727bf1c4d9d892fe83326533400',
#   'timestamp': 1619543422140,
#   'datetime': '2021-04-27T17:10:22.140Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 16.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151322833',
#    'orderListId': '-1',
#    'clientOrderId': 'web_a9501dc4daf34a4ca2a65bc03c0fd56c',
#    'price': '15.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543480601',
#    'updateTime': '1619543480601',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151322833',
#   'clientOrderId': 'web_a9501dc4daf34a4ca2a65bc03c0fd56c',
#   'timestamp': 1619543480601,
#   'datetime': '2021-04-27T17:11:20.601Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 15.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151323692',
#    'orderListId': '-1',
#    'clientOrderId': 'web_f429c4d3a90b49ed9b3c72597629563f',
#    'price': '14.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543505039',
#    'updateTime': '1619543505039',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151323692',
#   'clientOrderId': 'web_f429c4d3a90b49ed9b3c72597629563f',
#   'timestamp': 1619543505039,
#   'datetime': '2021-04-27T17:11:45.039Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 14.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 25.0,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151958026',
#    'orderListId': '-1',
#    'clientOrderId': 'x-R4BD3S82ab8f036d32537845330e23',
#    'price': '5.69900000',
#    'origQty': '3.50900000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619586921158',
#    'updateTime': '1619586921158',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151958026',
#   'clientOrderId': 'x-R4BD3S82ab8f036d32537845330e23',
#   'timestamp': 1619586921158,
#   'datetime': '2021-04-28T05:15:21.158Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 5.699,
#   'stopPrice': 0.0,
#   'amount': 3.509,
#   'cost': 0.0,
#   'average': None,
#   'filled': 0.0,
#   'remaining': 3.509,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': []}]

# %%
closed_order = exchange.fetch_closed_orders(symbol)

# %%
closed_order
# Out:
# [{'info': {'symbol': 'LUNAUSDT',
#    'orderId': '141612146',
#    'orderListId': '-1',
#    'clientOrderId': 'and_3b0684b6248f41349b5c24de5b06cbdf',
#    'price': '13.63810000',
#    'origQty': '49.16000000',
#    'executedQty': '49.16000000',
#    'cummulativeQuoteQty': '670.44899600',
#    'status': 'FILLED',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619069139146',
#    'updateTime': '1619069195122',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '141612146',
#   'clientOrderId': 'and_3b0684b6248f41349b5c24de5b06cbdf',
#   'timestamp': 1619069139146,
#   'datetime': '2021-04-22T05:25:39.146Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 13.6381,
#   'stopPrice': 0.0,
#   'amount': 49.16,
#   'cost': 670.448996,
#   'average': 13.6381,
#   'filled': 49.16,
#   'remaining': 0.0,
#   'status': 'closed',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '148291513',
#    'orderListId': '-1',
#    'clientOrderId': 'web_ad35a3e0accb44ed82efe4752e738f9c',
#    'price': '17.80000000',
#    'origQty': '49.11000000',
#    'executedQty': '49.11000000',
#    'cummulativeQuoteQty': '874.25622000',
#    'status': 'FILLED',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'SELL',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619364520823',
#    'updateTime': '1619364520823',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '148291513',
#   'clientOrderId': 'web_ad35a3e0accb44ed82efe4752e738f9c',
#   'timestamp': 1619364520823,
#   'datetime': '2021-04-25T15:28:40.823Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'sell',
#   'price': 17.8,
#   'stopPrice': 0.0,
#   'amount': 49.11,
#   'cost': 874.25622,
#   'average': 17.802,
#   'filled': 49.11,
#   'remaining': 0.0,
#   'status': 'closed',
#   'fee': None,
#   'trades': [],
#   'fees': []},
#  {'info': {'symbol': 'LUNAUSDT',
#    'orderId': '151319398',
#    'orderListId': '-1',
#    'clientOrderId': 'web_464dea3250fe4eeb9f92782d476957aa',
#    'price': '17.00000000',
#    'origQty': '25.00000000',
#    'executedQty': '25.00000000',
#    'cummulativeQuoteQty': '425.00000000',
#    'status': 'FILLED',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1619543389590',
#    'updateTime': '1619585307662',
#    'isWorking': True,
#    'origQuoteOrderQty': '0.00000000'},
#   'id': '151319398',
#   'clientOrderId': 'web_464dea3250fe4eeb9f92782d476957aa',
#   'timestamp': 1619543389590,
#   'datetime': '2021-04-27T17:09:49.590Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'LUNA/USDT',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'side': 'buy',
#   'price': 17.0,
#   'stopPrice': 0.0,
#   'amount': 25.0,
#   'cost': 425.0,
#   'average': 17.0,
#   'filled': 25.0,
#   'remaining': 0.0,
#   'status': 'closed',
#   'fee': None,
#   'trades': [],
#   'fees': []}]

# %%
test_id = '151319398'
test_order = exchange.fetch_order(test_id, symbol)

# %%
test_order
# Out:
# {'info': {'symbol': 'LUNAUSDT',
#   'orderId': '151319398',
#   'orderListId': '-1',
#   'clientOrderId': 'web_464dea3250fe4eeb9f92782d476957aa',
#   'price': '17.00000000',
#   'origQty': '25.00000000',
#   'executedQty': '25.00000000',
#   'cummulativeQuoteQty': '425.00000000',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': '1619543389590',
#   'updateTime': '1619585307662',
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  'id': '151319398',
#  'clientOrderId': 'web_464dea3250fe4eeb9f92782d476957aa',
#  'timestamp': 1619543389590,
#  'datetime': '2021-04-27T17:09:49.590Z',
#  'lastTradeTimestamp': None,
#  'symbol': 'LUNA/USDT',
#  'type': 'limit',
#  'timeInForce': 'GTC',
#  'postOnly': False,
#  'side': 'buy',
#  'price': 17.0,
#  'stopPrice': 0.0,
#  'amount': 25.0,
#  'cost': 425.0,
#  'average': 17.0,
#  'filled': 25.0,
#  'remaining': 0.0,
#  'status': 'closed',
#  'fee': None,
#  'trades': [],
#  'fees': []}

# %%
status = test_order['info']['status'] # use info status not global status

# %%
status
# Out:
# 'FILLED'

# %% [markdown]
# ### Balance

# %%
balance = exchange.fetch_balance()

# %%
pd.DataFrame(balance['info']['balances'])
# Out:
#          asset        free      locked
# 0          BTC  0.00000000  0.00000000
# 1          LTC  0.00000000  0.00000000
# 2          ETH  0.00000221  0.00000000
# 3          NEO  0.00000000  0.00000000
# 4          BNB  0.00000000  0.00000000
# ..         ...         ...         ...
# 407    1INCHUP  0.00000000  0.00000000
# 408  1INCHDOWN  0.00000000  0.00000000
# 409        MIR  0.00000000  0.00000000
# 410        BAR  0.00000000  0.00000000
# 411      FORTH  0.00000000  0.00000000
#
# [412 rows x 3 columns]

# %%
coin = symbol.split('/')[0]
balance[coin]
# Out:
# {'free': 24.97584, 'used': 0.0, 'total': 24.97584}
